# %%
import requests
import re
import html
import sqlite3
import time
    
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.action_chains import ActionChains

# %%
def search_lpsg(search_terms):
    
    s = requests.session()
    
    if type(search_terms) is not list:
        search_terms = [search_terms]
        
    results = []
    
    for terms in search_terms:
        
        data = {'keywords': terms.replace(' ','+')}
        r = s.post('https://www.lpsg.com/search/search',data= data)

        redirect = r.url
        #temp = redirect.split('/?q=')
        #page_url = temp[0] + ('/?page={}&amp;q=') + temp[1]

        if 'LPSG - Error' in r.text or 'No results found' in r.text:
            #print('Not found')
            return None

        results = re.findall('Showing results .* of (\d+)', r.text)[0]

        try:
            max_pages = re.findall('Page . of (\d+)',r.text)[0]
        except:
            max_pages = 1

        res_string = 'LPSG found {} pages {} results: {}'.format(max_pages,results,redirect)
        results.append(res_string)
    
    return(results.join('/n'))

def db_search1(query):
    db_location = '/home/larkaa/code/dn_tools/usr_lists/user_list.db'
    conn = sqlite3.connect(db_location)
    c = conn.cursor()
    c.row_factory = lambda cursor, row: row[0]
    cursor = c.execute(query)
    res = cursor.fetchall()
    conn.close()
    
    return res

def search_mg(search_terms):
    time_sleep=2
    url = 'https://www.malegeneral.com/cam/dongs/'
    chrome_options = Options()  
    chrome_options.add_argument("--headless")
    chrome_options.add_argument('--no-sandbox')
    chrome_options.add_argument('--disable-dev-shm-usage')
    ## colab
    #browser = webdriver.Chrome('chromedriver', options=chrome_options)
    browser =  webdriver.Chrome(executable_path='/usr/bin/chromedriver', options=chrome_options)
    # windows
    #browser =  webdriver.Chrome(executable_path='C:\\Users\\Drew\\code\\opera_tools\\chromedriver' , options=chrome_options)

    if type(search_terms) is not list:
        search_terms = [search_terms]
        
    results = []
    
    for terms in search_terms:
        
        browser.get(url)
        
        time.sleep(time_sleep)

        #fill in search
        form1 = browser.find_elements_by_xpath('//input[contains(@class,"gsc-input")]')[0]
        form1.send_keys(terms)

        #press button
        button1 = browser.find_element_by_xpath('//button[contains(@class,"gsc-search-button-v2")]')
        button1.click()
        time.sleep(time_sleep+2)

        #close other tabs
        browser.close()

        #switch to new tab
        browser.switch_to.window(browser.window_handles[0])
        source = browser.page_source

        if 'No Results' in source:
            continue
        else:
            #number of matches
            try:
                num_res = re.findall('About (\d+) result', source)[0]
            except:
                print(terms)
                return(browser.page_source)

            #links on first page
            pages = re.findall('https://www.malegeneral.com.+?php', source)
            pages = list(set(pages))

            results.append([num_res, pages])
            print(terms, num_res, pages)
            #print(pages)
        
        time.sleep(time_sleep)
        
    return(results)

# %%
query = 'select username from USERS' 
user_list = db_search1(query)

temp = search_lpsg(user_list)

for i in res:
    print(i)

# %%
query = 'select username from USERS' 
user_list = db_search1(query)
res = search_mg(user_list)
# Out:
# BlokBuster 1 []
# aussie91 2 ['https://www.malegeneral.com/archive/dongs-2017/358.php', 'https://www.malegeneral.com/archive/dongs-2017/res/42164.php']
# XIV 9 ['https://www.malegeneral.com/archive/dongs-2019/res/7363.php', 'https://www.malegeneral.com/archive/dongs-2018/res/43607.php', 'https://www.malegeneral.com/archive/dongs-2017/res/56844.php', 'https://www.malegeneral.com/archive/dongs-2017/res/47502.php', 'https://www.malegeneral.com/archive/dongs-2018/res/1775.php', 'https://www.malegeneral.com/archive/dongs-2018/36.php', 'https://www.malegeneral.com/archive/dongs-2018/res/82706.php', 'https://www.malegeneral.com/archive/dongs-2017/220.php', 'https://www.malegeneral.com/archive/dongs-2018/res/8701.php']
# kasper 2 ['https://www.malegeneral.com/archive/dongs-2018/res/60853.php', 'https://www.malegeneral.com/archive/dongs-2017/63.php']
# edu-m 1 []
# lascivious 5 ['https://www.malegeneral.com/archive/dongs-2018/res/45494.php']
# ...

# %%
for i in res:
    print(i)

# %%
#proxy settings

PROXY = "23.23.23.23:3128" # IP:PORT or HOST:PORT

chrome_options = webdriver.ChromeOptions()
chrome_options.add_argument('--proxy-server={}'.format(PROXY))

chrome = webdriver.Chrome(options=chrome_options)
chrome.get("http://whatismyipaddress.com")

# %%
browser.get(url)

# %%
browser.switch_to.window(browser.window_handles[0])

# %%
import requests
import shutil
from pathlib import Path

def dl_link(addy,session):

    dl_name = addy.split('/')[-1].split('.')[0]+'.jpg'
    dl_name = html.unescape(dl_name)
    #my_file = Path(dl_path+'/'+dl_name)
    path = Path('/home/larkaa/code/tumblr_crawl/'+dl_name)
    
    if not path.is_file():
        #print("new content {} {}".format(path,dl_name))
        r = session.get(addy, stream=True)
        if r.status_code == 200:
            with open(path, 'wb') as f:
                r.raw.decode_content = True
                shutil.copyfileobj(r.raw, f)
                print(f)
        else:
            print(r.status_code)
            
        
        return
    else:
        return

# %%
dl_link(links[0],s)
# Out:
# 403

# %%
ls
# Out:
# crawl_lpsg.ipynb  gwip.txt      README.md                tumblr_crawler.py*
# dedup.ipynb       LICENSE       redo_tumblrcrawl.ipynb*  verify_image.py
# dedup.py*         __pycache__/  tumblr_crawler_old.py*   Verify_images.ipynb

# %%
## get max page number
pages_temp = re.findall('Page \d of \d.+?<nav>(.+?)</nav',rh)
pages = [a for a in pages_temp if 'page-' in a][0]
max_page = max([int(i) for i in re.findall('page-(\d)',pages)])
max_page
# Out:
# 6

# %%
img_list
# Out:
# ['https://www.lpsg.com/attachments/311209_10151317076935115_559143886_n-jpg.7706151/',
#  'https://www.lpsg.com/attachments/11230531_1099259366767244_199882189_n-jpg.7706161/',
#  'https://www.lpsg.com/attachments/12805677_10153853597325115_6850560999524796101_n-jpg.7706171/',
#  'https://www.lpsg.com/attachments/26166212_10155785689025115_622941381018766393_n-jpg.7706181/',
#  'https://www.lpsg.com/attachments/images-jpg.7706191/',
#  'https://www.lpsg.com/attachments/img-20180602-wa0001-jpg.7706201/',
#  'https://www.lpsg.com/attachments/img-20180602-wa0003-jpg.7706211/',
#  'https://www.lpsg.com/attachments/img-20180602-wa0005-jpg.7706221/',
#  'https://www.lpsg.com/attachments/img-20180602-wa0006-jpg.7706231/',
#  'https://www.lpsg.com/attachments/img-20180602-wa0007-jpg.7706241/',
#  'https://www.lpsg.com/attachments/img-20180602-wa0008-jpg.7706251/',
#  'https://www.lpsg.com/attachments/img-20180602-wa0016-jpg.7706281/',
# ...

# %%
# get images
img_list = re.findall('="(https:\S+?attachments\S+?)"',rh)
s = requests.session()
for i in img_list:
    #print(i)
    temp = i.strip().split('/')[-2]
    #print(temp)
    
    if 'jpg' in temp:
        dl_name = temp.split('-jpg')[0] + '.jpg'
    else:
        dl_name = temp + '.jpg'
    #print(dl_name)
    dl_helper(i,dl_name,s)

# %%
url = 'https://www.lpsg.com'
s = requests.session()

headers = {'User-Agent': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/79.0.3945.88 Safari/537.36',
   'Accept-Charset': 'ISO-8859-1,utf-8;q=0.7,*;q=0.3',
   'Accept-Encoding': 'gzip, deflate, br',
   'Accept-Language': 'en-US,en;q=0.8',
   'Connection': 'keep-alive',
          'Cookie':'RNLBSERVERID=ded4149; _ga=GA1.2.388188376.1562179427;',
          'xf_session':'f54d3460c3f8e0a22e0ad30d17177c11'}

r = s.get('https://dudesnude.com/login.php', timeout=10)
payload = {'_xfToken': '',
           'redirect': 'https://www.lpsg.com/',
       'login':'procrastinator80@hotmail.com',
        'password':'Uj66SpWy4PTwSW8',
          'register':'0',
          'cookie_check':'1'}    
#phpsess=re.findall('PHPSESSID" value="(.+?)"',r.text)
#s_token=re.findall('s_token" value="(.+?)"',r.text)
#payload['PHPSESSID'] = phpsess
#payload['s_token'] = s_token
payload['redirect'] = 'https://www.lpsg.com'

r = s.post(url, data=payload, timeout=10)

r.text
# Out:
# '<!DOCTYPE html>\n\n\n\n\n\n\n\n\n\t\n\t\n\t\t\n\t\n\n\n\n\n\t\n\n\n\n\n\n\n\n\n\n\t\n\n\n\n\n\t\n\n\n\n\n\t\n\n\n\n\n\n\t\n\n\n\n\n\t\n\t\t\n\t\n\t\n\t\n\t\t\n\t\n\n\n<html id="XenForo" lang="en-US" dir="LTR" class="Public NoJs uix_javascriptNeedsInit LoggedOut Sidebar  Responsive pageIsLtr   hasTabLinks  hasSearch   is-sidebarOpen hasLeftSidebar is-setWidth navStyle_0 pageStyle_2 hasFlexbox" xmlns:fb="http://www.facebook.com/2008/fbml">\n<head>\n\n\n\t<meta charset="utf-8" />\n\t<meta http-equiv="X-UA-Compatible" content="IE=Edge,chrome=1" />\n\t<meta name="apple-mobile-web-app-capable" content="yes">\n\t <meta name="apple-mobile-web-app-status-bar-style" content="translucent">\n\t <meta name="format-detection" content="telephone=no">\n\n\t\n\t\t\n\n\t<meta name="viewport" content="width=device-width, initial-scale=1" />\n\n<meta property="rellect-viewport" content="width=device-width, initial-scale=1" />\n\t\n\t\n\t\t<base href="https://www.lpsg.com/" />\n\t\t<script>\n\t\t\tvar _
# ...

# %%
headers = {
    
    'Accept':'image/webp,image/apng,image/*,*/*;q=0.8',
    'Accept-Encoding': 'gzip, deflate, br',
    'Cookie':'RNLBSERVERID=ded4149; _ga=GA1.2.388188376.1562179427;',
          'xf_session':'f54d3460c3f8e0a22e0ad30d17177c11',
    'Connection': 'keep-alive',
    'DNT':'1',
    'Host':'www.lpsg.com',
    'Referer':'',
    'Sec-Fetch-Mode':'no-cors',
    'Sec-Fetch-Site': 'same-origin'
}
headers['Referer']='https://www.lpsg.com/threads/jeff-tetreault.408689/page-6'

test = s.get(img_list[1], headers = headers)
test
# Out:
# <Response [403]>
